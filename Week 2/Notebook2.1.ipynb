# %% [markdown]
# # AAI614: Data Science & its Applications
#
# *Notebook 2.1: Practice with Pandas*
#
# <a href="https://colab.research.google.com/github/harmanani/AAI614/blob/main/Week%202/Notebook2.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# *This notebook contains excerpts from the [Pandas in Action](https://www.manning.com/books/pandas-in-action) by Boris Paskhaver.*

# %% [markdown]
# ### 1. Read the file

# %%
import pandas as pd
import numpy as np
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

nba = pd.read_csv("https://raw.githubusercontent.com/harmanani/AAI614/main/Week%202/nba.csv")

# %% [markdown]
# ### 1. Shared and Exclusive Attributes between Series and DataFrames

# %%
pd.Series([1, 2, 3]).dtype
# Out:
# dtype('int64')

# %%
nba.dtypes
# Out:
# Name        object
# Team        object
# Position    object
# Birthday    object
# Salary       int64
# dtype: object

# %%
nba.dtypes.value_counts()
# Out:
# object    4
# int64     1
# Name: count, dtype: int64

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=450, step=1)

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Position', 'Birthday', 'Salary'], dtype='object')

# %%
nba.ndim
# Out:
# 2

# %%
nba.shape
# Out:
# (450, 5)

# %%
nba.size
# Out:
# 2250

# %%
nba.count()
# Out:
# Name        450
# Team        450
# Position    450
# Birthday    450
# Salary      450
# dtype: int64

# %%
nba.count().sum()
# Out:
# 2250

# %%
data = {
    "A": [1, np.nan],
    "B": [2, 3]
}

df = pd.DataFrame(data)
df
# Out:
#      A  B
# 0  1.0  2
# 1  NaN  3

# %%
df.size
# Out:
# 4

# %%
df.count()
# Out:
# A    1
# B    2
# dtype: int64

# %%
df.count().sum()
# Out:
# 3

# %% [markdown]
# ### 2. Shared Methods between Series and DataFrames

# %%
nba.head(2)
# Out:
#              Name                Team Position Birthday   Salary
# 0    Shake Milton  Philadelphia 76ers       SG  9/26/96  1445697
# 1  Christian Wood     Detroit Pistons       PF  9/27/95  1645357

# %%
nba.tail(n = 3)
# Out:
#               Name                 Team Position  Birthday    Salary
# 447    Robin Lopez      Milwaukee Bucks        C    4/1/88   4767000
# 448  Collin Sexton  Cleveland Cavaliers       PG    1/4/99   4764960
# 449    Ricky Rubio         Phoenix Suns       PG  10/21/90  16200000

# %%
nba.tail()
# Out:
#               Name                 Team Position  Birthday    Salary
# 445  Austin Rivers      Houston Rockets       PG    8/1/92   2174310
# 446    Harry Giles     Sacramento Kings       PF   4/22/98   2578800
# 447    Robin Lopez      Milwaukee Bucks        C    4/1/88   4767000
# 448  Collin Sexton  Cleveland Cavaliers       PG    1/4/99   4764960
# 449    Ricky Rubio         Phoenix Suns       PG  10/21/90  16200000

# %%
nba.sample(3)
# Out:
#                  Name                   Team Position Birthday    Salary
# 64        Theo Pinson          Brooklyn Nets       SG  11/5/95   1445697
# 65   Danilo Gallinari  Oklahoma City Thunder       PF   8/8/88  22615559
# 404    Doug McDermott         Indiana Pacers       PF   1/3/92   7333333

# %%
nba.nunique()
# Out:
# Name        450
# Team         30
# Position      9
# Birthday    430
# Salary      269
# dtype: int64

# %%
nba.max()
# Out:
# Name            Zylan Cheatham
# Team        Washington Wizards
# Position                    SG
# Birthday                9/9/93
# Salary                40231758
# dtype: object

# %%
nba.min()
# Out:
# Name         Aaron Gordon
# Team        Atlanta Hawks
# Position                C
# Birthday          1/10/98
# Salary              79568
# dtype: object

# %%
nba.nlargest(n = 4, columns = "Salary")
# Out:
#                   Name                   Team Position  Birthday    Salary
# 205      Stephen Curry  Golden State Warriors       PG   3/14/88  40231758
# 38          Chris Paul  Oklahoma City Thunder       PG    5/6/85  38506482
# 219  Russell Westbrook        Houston Rockets       PG  11/12/88  38506482
# 251          John Wall     Washington Wizards       PG    9/6/90  38199000

# %%
nba['Birthday'] = pd.to_datetime(nba['Birthday'])
# Out:
# /var/folders/7c/dnx_f4dn5jlcgjk9d2b920zh0000gn/T/ipykernel_44399/101016257.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   nba['Birthday'] = pd.to_datetime(nba['Birthday'])

# %%
nba.nsmallest(n = 3, columns = ["Birthday"])
# Out:
#               Name             Team Position   Birthday   Salary
# 98    Vince Carter    Atlanta Hawks       PF 1977-01-26  2564753
# 196  Udonis Haslem       Miami Heat        C 1980-06-09  2564753
# 262    Kyle Korver  Milwaukee Bucks       PF 1981-03-17  6004753

# %% [markdown]
# #### The following should give an error.  No need to panic :-)

# %%
#nba.sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[342], line 1
# ----> 1 nba.sum()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:11512, in NDFrame._add_numeric_operations.<locals>.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11493 @doc(  # type: ignore[misc]
#   11494     _num_doc,
#   11495     desc="Return the sum of the values over the requested axis.\n\n"
#    (...)
#   11510     **kwargs,
#   11511 ):
# > 11512     return NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:11280, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11272 def sum(
#   11273     self,
#   11274     axis: Axis | None = None,
#    (...)
#   11278     **kwargs,
#   11279 ):
# > 11280     return self._min_count_stat_function(
#   11281         "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   11282     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:11263, in NDFrame._min_count_stat_function(self, name, func, axis, skipna, numeric_only, min_count, **kwargs)
#   11260 if axis is None:
#   11261     axis = self._stat_axis_number
# > 11263 return self._reduce(
#   11264     func,
#   11265     name=name,
#   11266     axis=axis,
#   11267     skipna=skipna,
#   11268     numeric_only=numeric_only,
#   11269     min_count=min_count,
#   11270 )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:10519, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10515     df = df.T
#   10517 # After possibly _get_data and transposing, we are now in the
#   10518 #  simple case where we can use BlockManager.reduce
# > 10519 res = df._mgr.reduce(blk_func)
#   10520 out = df._constructor(res).iloc[0]
#   10521 if out_dtype is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/internals/managers.py:1534, in BlockManager.reduce(self, func)
#    1532 res_blocks: list[Block] = []
#    1533 for blk in self.blocks:
# -> 1534     nbs = blk.reduce(func)
#    1535     res_blocks.extend(nbs)
#    1537 index = Index([None])  # placeholder
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/internals/blocks.py:339, in Block.reduce(self, func)
#     333 @final
#     334 def reduce(self, func) -> list[Block]:
#     335     # We will apply the function and reshape the result into a single-row
#     336     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     337     assert self.ndim == 2
# --> 339     result = func(self.values)
#     341     if self.values.ndim == 1:
#     342         # TODO(EA2D): special case not needed with 2D EAs
#     343         res_values = np.array([[result]])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:10479, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   10475 if isinstance(values, ExtensionArray):
#   10476     if not is_1d_only_ea_dtype(values.dtype) and not isinstance(
#   10477         self._mgr, ArrayManager
#   10478     ):
# > 10479         return values._reduce(name, axis=1, skipna=skipna, **kwds)
#   10480     return values._reduce(name, skipna=skipna, **kwds)
#   10481 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/arrays/base.py:1440, in ExtensionArray._reduce(self, name, skipna, **kwargs)
#    1438 meth = getattr(self, name, None)
#    1439 if meth is None:
# -> 1440     raise TypeError(
#    1441         f"'{type(self).__name__}' with dtype {self.dtype} "
#    1442         f"does not support reduction '{name}'"
#    1443     )
#    1444 return meth(skipna=skipna, **kwargs)
#
# TypeError: 'DatetimeArray' with dtype datetime64[ns] does not support reduction 'sum'

# %%
nba.sum(numeric_only = True)

# %%
nba.mean(numeric_only = True)

# %%
nba.median(numeric_only = True)

# %%
nba.mode(numeric_only = True)

# %%
nba.std(numeric_only = True)

# %% [markdown]
# ## 3. Sorting a DataFrame

# %% [markdown]
# ### 3.1 Sorting by Single Column

# %%
# The two lines below are equivalent
nba.sort_values("Name")
nba.sort_values(by = "Name")

# %%
nba.sort_values("Name", ascending = False).head()

# %%
nba.sort_values("Birthday", ascending = False).head()

# %% [markdown]
# ### 4.2 Sorting by Multiple Columns

# %%
nba.sort_values(by = ["Team", "Name"])

# %%
nba.sort_values(["Team", "Name"], ascending = False)

# %%
nba.sort_values(
    by = ["Team", "Salary"], ascending = [True, False]
)

# %%
nba = nba.sort_values(
    by = ["Team", "Salary"],
    ascending = [True, False]
)

# %% [markdown]
# ## 5 Sorting by Index

# %%
nba.head()

# %% [markdown]
# ### 5.1 Sorting by Row Index

# %%
# The two lines below are equivalent
nba.sort_index().head()
nba.sort_index(ascending = True).head()

# %%
nba.sort_index(ascending = False).head()

# %%
nba = nba.sort_index()

# %% [markdown]
# ### 5.2 Sorting by Column Index

# %%
# The two lines below are equivalent
nba.sort_index(axis = "columns").head()
nba.sort_index(axis = 1).head()

# %%
nba.sort_index(axis = "columns", ascending = False).head()

# %% [markdown]
# ## 5.3 Setting a New Index

# %%
# The two lines below are equivalent
nba.set_index(keys = "Name")
nba.set_index("Name")

# %% [markdown]
# ## 6 Selecting Columns and Rows from a DataFrame

# %% [markdown]
# ### 6.1 Selecting a Single Column from a DataFrame

# %%
nba.Salary

# %%
nba["Position"]

# %% [markdown]
# ### 6.2 Selecting Multiple Columns from a DataFrame

# %%
nba[["Salary", "Birthday"]].head()

# %%
nba[["Birthday", "Salary"]].head()

# %%
nba.select_dtypes(include = "object")

# %%
nba.select_dtypes(exclude = ["object", "int"])

# %% [markdown]
# ## 7 Selecting Rows from a DataFrame

# %% [markdown]
# ### 7.1 Extracting Rows by Index Label

# %%
nba

# %%
nba.index = nba["Name"]

# %%
nba.loc["LeBron James"]

# %%
nba.loc[["Kawhi Leonard", "Paul George"]]

# %%
nba.loc[["Paul George", "Kawhi Leonard"]]

# %%
nba.sort_index().loc["Otto Porter":"Patrick Beverley"]

# %%
players = ["Otto Porter", "PJ Dozier", "PJ Washington"]
players[0:2]

# %%
nba.sort_index().loc["Zach Collins":]

# %%
nba.sort_index().loc[:"Al Horford"]

# %% [markdown]
# **NOTE**: I've commented out the code below so that the Notebook can run without raising an error.

# %%
#nba.loc["Bugs Bunny"]

# %% [markdown]
# ### 7.2 Extracting Rows by Index Position

# %%
nba.iloc[300]

# %%
nba.iloc[[100, 200, 300, 400]]

# %%
nba.iloc[400:404]

# %%
nba.iloc[:2]

# %%
nba.iloc[447:]

# %%
nba.iloc[-10:-6]

# %%
nba.iloc[0:10:2]

# %% [markdown]
# ### 7.3 Extracting Values from Specific Columns

# %%
nba['Team'].loc["Giannis Antetokounmpo"]

# %%
nba.loc["James Harden", ["Position", "Birthday"]]

# %%
nba.loc[
    ["Russell Westbrook", "Anthony Davis"],
    ["Team", "Salary"]
]

# %%
nba.loc["Joel Embiid", "Position":"Salary"]

# %%
nba.loc["Joel Embiid", "Salary":"Position"]

# %%
nba.iloc[57, 3]

# %%
nba.iloc[100:104, :3]

# %%
nba.at["Austin Rivers", "Birthday"]

# %%
nba.iat[263, 1]

# %%
# %%timeit
nba.at["Austin Rivers", "Birthday"]

# %%
# %%timeit
nba.loc["Austin Rivers", "Birthday"]

# %%
# %%timeit
nba.iat[263, 1]

# %%
# %%timeit
nba.iloc[263, 1]

# %% [markdown]
# ## 8 Extracting Values from Series

# %%
nba["Salary"].loc["Damian Lillard"]

# %%
nba["Salary"].at["Damian Lillard"]

# %%
nba["Salary"].iloc[234]

# %%
nba["Salary"].iat[234]

# %% [markdown]
# ## 9 Renaming Columns or Rows

# %%
nba.columns

# %%
nba.columns = ["Team", "Position", "Date of Birth", "Pay"]
nba.head(1)

# %%
nba.rename(columns = { "Date of Birth": "Birthday" })

# %%
nba = nba.rename(columns = { "Date of Birth": "Birthday" })

# %%
nba.loc["Giannis Antetokounmpo"]

# %%
nba = nba.rename(
    index = { "Giannis Antetokounmpo": "Greek Freak" }    
)

# %%
nba.loc["Greek Freak"]

# %% [markdown]
# ## 10 Resetting an Index

# %%
nba.set_index("Team").head()

# %%
nba.reset_index().head()

# %%
nba.reset_index().set_index("Team").head()

# %%
nba = nba.reset_index().set_index("Team")
