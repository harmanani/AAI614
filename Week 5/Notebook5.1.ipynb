# %% [markdown]
# # AAI614: Data Science & its Applications
#
# *Notebook 5.1: Experiment with Regression*
#
# <a href="https://colab.research.google.com/github/harmanani/AAI614/blob/main/Week%205/Notebook5.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing the libraries

# %%
import numpy, pandas as pd
import matplotlib, matplotlib.pyplot as plt
import sklearn.linear_model as lm

# %% [markdown]
# ## Importing the dataset

# %%
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

sap = pd.read_csv('https://raw.githubusercontent.com/harmanani/AAI614/main/Week%205/sapXXI.csv').set_index("Date")

# %% [markdown]
# ## Select a "linearly looking" part

# %%
sap.index = pd.to_datetime(sap.index)
sap_linear = sap.ix[sap.index > pd.to_datetime('2009-01-01')]

# %% [markdown]
# ## Prepare the model and fit it

# %%
olm = lm.LinearRegression()
X = numpy.array([x.toordinal() for x in sap_linear.index])[:, numpy.newaxis]
y = sap_linear['Close']
olm.fit(X, y)

# %% [markdown]
# ## Predict values

# %%
yp = [olm.predict(x.toordinal())[0] for x in sap_linear.index]

# %% [markdown]
# ## Evaluate the model

# %%
olm_score = olm.score(X, y)

# %% [markdown]
# ## Draws the original data set, the predicted line, and the model score

# %%
# Select a nice plotting style
matplotlib.style.use("ggplot")
# Plot both data sets
plt.plot(sap_linear.index, y)
plt.plot(sap_linear.index, yp)
# Add decorations
plt.title("OLS Regression")
plt.xlabel("Year")
plt.ylabel("S&P 500 (closing)")
plt.legend(["Actual", "Predicted"], loc="lower right")
plt.annotate("Score=%.3f" % olm_score, xy=(pd.to_datetime('2010-06-01'), 1900))
